# %% [markdown]
# ##### Import libs

# %%
import pandas as pd
from decouple import config
import numpy as np
# Load enviroment variables.
ROOT_PATH       = config('ROOT_PATH')
DATA_RAW_PATH   = config('DATA_RAW_PATH')

# %% [markdown]
# ##### Load data

# %%
data_tmp = pd.read_csv(ROOT_PATH+DATA_RAW_PATH+'dataframe_merged.csv')

# %% [markdown]
# ##### Organizing data

# %%
data_tmp.insert(2,'lat',data_tmp.pop('lat'))
data_tmp
# Out:
#        type         id        lat        lon BANHEIRA_DE_HIDROMASSAGEM  BOX  \
# 0     house  892986759 -23.663303 -46.642494                       NAO  NAO
# 1     house  893513303 -23.671671 -46.691886                       NAO  SIM
# 2     house  893567381 -23.462255 -46.555363                       NAO  NAO
# 3     house  893426340 -23.554803 -46.596351                       SIM  SIM
# 4     house  893475416 -23.675248 -46.609885                       NAO  NAO
# ...     ...        ...        ...        ...                       ...  ...
# 9974  house  893703984 -23.540389 -46.652610                       NAO  NAO
# 9975  house  893697876 -23.494918 -46.740010                       NAO  SIM
# 9976  house  893669474 -23.587723 -46.582399                       NAO  NAO
# 9977  house  893688435 -23.625045 -46.688631                       NAO  SIM
# 9978  house  893301415 -23.501925 -46.629490                       NAO  SIM
#
#             VARANDA PISCINA_PRIVATIVA ARMARIOS_EMBUTIDOS_NO_QUARTO  \
# 0     NAO_INFORMADO               NAO                          NAO
# 1               NAO               NAO                          NAO
# 2               SIM               NAO                          NAO
# 3               NAO               NAO                          NAO
# 4               SIM               NAO                          NAO
# ...             ...               ...                          ...
# 9974            NAO               NAO                          NAO
# 9975            NAO               SIM                          NAO
# 9976            SIM               NAO                          SIM
# 9977  NAO_INFORMADO               NAO                          SIM
# 9978            SIM               NAO                          SIM
#
#      ARMARIOS_NOS_BANHEIROS  ... GELADEIRA_INCLUSO BANHEIRO_ADAPTADO  \
# 0                       NAO  ...               NAO     NAO_INFORMADO
# 1                       SIM  ...               NAO               NAO
# 2                       NAO  ...               NAO               NAO
# 3                       SIM  ...               NAO               NAO
# 4                       SIM  ...               NAO               NAO
# ...                     ...  ...               ...               ...
# 9974                    NAO  ...               NAO               NAO
# 9975                    NAO  ...               NAO               NAO
# 9976                    SIM  ...               NAO               SIM
# 9977                    SIM  ...               NAO     NAO_INFORMADO
# 9978                    SIM  ...               NAO               NAO
#
#              CLOSET COZINHA_AMERICANA MESAS_E_CADEIRAS_DE_ESCRITORIO  \
# 0     NAO_INFORMADO     NAO_INFORMADO                  NAO_INFORMADO
# 1               NAO               NAO                            NAO
# 2               NAO               NAO                            NAO
# 3               NAO               NAO                            SIM
# 4               NAO               NAO                            NAO
# ...             ...               ...                            ...
# 9974            NAO               NAO                            NAO
# 9975            NAO               NAO                            NAO
# 9976            NAO               NAO                            NAO
# 9977  NAO_INFORMADO     NAO_INFORMADO                  NAO_INFORMADO
# 9978            NAO               SIM                            NAO
#
#              JARDIM QUARTOS_E_CORREDORES_COM_PORTAS_AMPLAS        QUINTAL  \
# 0     NAO_INFORMADO                          NAO_INFORMADO  NAO_INFORMADO
# 1               NAO                                    NAO            SIM
# 2               NAO                                    NAO            NAO
# 3               NAO                                    NAO            NAO
# 4               NAO                                    NAO            NAO
# ...             ...                                    ...            ...
# 9974            NAO                                    NAO            NAO
# 9975            NAO                                    NAO            NAO
# 9976            SIM                                    SIM            SIM
# 9977  NAO_INFORMADO                          NAO_INFORMADO  NAO_INFORMADO
# 9978            NAO                                    NAO            NAO
#
#      SOMENTE_UMA_CASA_NO_TERRENO AREA_DE_SERVICO
# 0                  NAO_INFORMADO             SIM
# 1                            SIM             SIM
# 2                            NAO             SIM
# 3                            NAO             NAO
# 4                            NAO             SIM
# ...                          ...             ...
# 9974                         NAO             SIM
# 9975                         NAO             NAO
# 9976                         SIM             SIM
# 9977               NAO_INFORMADO   NAO_INFORMADO
# 9978                         NAO             SIM
#
# [9979 rows x 29 columns]
