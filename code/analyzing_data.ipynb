# %% [markdown]
# ##### Import libs

# %%
import pandas as pd
from decouple import config
import numpy as np
import ast
from geopy.geocoders import Nominatim
# Load enviroment variables.
ROOT_PATH       = config('ROOT_PATH')
DATA_RAW_PATH   = config('DATA_RAW_PATH')
pd.options.display.max_columns = 100

# %% [markdown]
# ##### Methods

# %%
def get_geolocation (address:str)-> tuple[float,float] :
    '''
        This method receives an address and return your geolocation.

        Parameters : 
            address = A address to take geolocation
        Ex :
            return_geolocation('Rua José Gáspar')
        Returns :
            (-23.6624262, -46.6441204)
    '''
    geolocator = Nominatim(user_agent='foursquare_agent')
    location = geolocator.geocode(address)
    lat = location.latitude
    long = location.longitude
    return lat, long

# %%
def mount_filtered_dataframe (dataframe:pd.DataFrame, city_to_search:str,list_neighborhood:list)-> pd.DataFrame :
    '''
        This method receives a dataframe, city and list of neighborhood to looking for.

        Parameters : 
            dataframe : A dataframe with data to filter
            city_to_search : A name of city to search properties
            list_neighborhood : A list that contains the neighborhoods to looking for.
        Ex :
            neighborhoods = [
                'Bela Vista','Bom Retiro','Cambuci','Consolação',
                'Sé','Higienópolis','Liberdade','Santa Cecília'
                ]
            mount_filtered_dataframe(data_tmp, 'São Paulo', neighborhoods)
        Returns :
            dataframe with filtered data.
    '''
    dataframe_ = pd.DataFrame()
    for neighborhood in list_neighborhood:
        dataframe_ = pd.concat([dataframe_,dataframe.loc[(dataframe['city'] == city_to_search) & (dataframe['neighborhood'] == neighborhood)]],axis=0)
    return dataframe_.reset_index(drop=True)

# %% [markdown]
# ##### Load data

# %%
data_tmp = pd.read_csv(ROOT_PATH+DATA_RAW_PATH+'dataframe_merged.csv')
data_raw = pd.read_csv(ROOT_PATH+DATA_RAW_PATH+'dataframe_raw_properties.csv')
# Out:
# C:\Users\Nophaie\AppData\Local\Temp\ipykernel_9944\3593990270.py:2: DtypeWarning: Columns (73) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_raw = pd.read_csv(ROOT_PATH+DATA_RAW_PATH+'dataframe_raw_properties.csv')

# %% [markdown]
# ##### Processing data

# %%
# Transforming string in dict
data_raw['address'] = data_raw['address'].apply(lambda x: ast.literal_eval(x))
# Creating columns
data_raw['street'] = data_raw['address'].apply(lambda x: x['street'])
data_raw['neighborhood'] = data_raw['address'].apply(lambda x: x.get('neighborhood',np.nan))

# %% [markdown]
# ##### Organizing data

# %%
# Reorganizing data
data_tmp.insert(2,'lat',data_tmp.pop('lat'))
data_tmp
# Out:
#        type         id        lat        lon BANHEIRA_DE_HIDROMASSAGEM  BOX  \
# 0     house  892986759 -23.663303 -46.642494                       NAO  NAO
# 1     house  893513303 -23.671671 -46.691886                       NAO  SIM
# 2     house  893567381 -23.462255 -46.555363                       NAO  NAO
# 3     house  893426340 -23.554803 -46.596351                       SIM  SIM
# 4     house  893475416 -23.675248 -46.609885                       NAO  NAO
# ...     ...        ...        ...        ...                       ...  ...
# 9974  house  893703984 -23.540389 -46.652610                       NAO  NAO
# 9975  house  893697876 -23.494918 -46.740010                       NAO  SIM
# 9976  house  893669474 -23.587723 -46.582399                       NAO  NAO
# 9977  house  893688435 -23.625045 -46.688631                       NAO  SIM
# 9978  house  893301415 -23.501925 -46.629490                       NAO  SIM
#
#             VARANDA PISCINA_PRIVATIVA ARMARIOS_EMBUTIDOS_NO_QUARTO  \
# 0     NAO_INFORMADO               NAO                          NAO
# 1               NAO               NAO                          NAO
# 2               SIM               NAO                          NAO
# 3               NAO               NAO                          NAO
# 4               SIM               NAO                          NAO
# ...             ...               ...                          ...
# 9974            NAO               NAO                          NAO
# 9975            NAO               SIM                          NAO
# 9976            SIM               NAO                          SIM
# 9977  NAO_INFORMADO               NAO                          SIM
# 9978            SIM               NAO                          SIM
#
#      ARMARIOS_NOS_BANHEIROS ARMARIOS_NA_COZINHA AR_CONDICIONADO  \
# 0                       NAO                 SIM             NAO
# 1                       SIM                 SIM             NAO
# 2                       NAO                 NAO             NAO
# 3                       SIM                 SIM             NAO
# 4                       SIM                 NAO             NAO
# ...                     ...                 ...             ...
# 9974                    NAO                 NAO             NAO
# 9975                    NAO                 SIM             NAO
# 9976                    SIM                 SIM             NAO
# 9977                    SIM                 SIM             NAO
# 9978                    SIM                 SIM             NAO
#
#      CHUVEIRO_A_GAS QUARTO_DE_SERVICO BANHEIRO_DE_SERVICO VARANDA_GOURMET  \
# 0               NAO               NAO                 SIM             NAO
# 1               NAO               SIM                 SIM             NAO
# 2               NAO               NAO                 NAO             NAO
# 3               NAO               NAO                 SIM             NAO
# 4               NAO               NAO                 NAO             NAO
# ...             ...               ...                 ...             ...
# 9974            NAO               NAO                 NAO             NAO
# 9975            NAO               SIM                 SIM             SIM
# 9976            NAO               SIM                 SIM             NAO
# 9977            NAO               NAO                 NAO             NAO
# 9978            SIM               SIM                 NAO             SIM
#
#      APARTAMENTO_COBERTURA QUARTO_EXTRA_REVERSIVEL FOGAO_INCLUSO  \
# 0                      NAO                     NAO           NAO
# 1                      NAO                     NAO           SIM
# 2                      NAO                     NAO           NAO
# 3                      NAO                     NAO           NAO
# 4                      NAO                     NAO           NAO
# ...                    ...                     ...           ...
# 9974                   NAO                     NAO           NAO
# 9975                   NAO                     SIM           NAO
# 9976                   NAO                     SIM           NAO
# 9977                   NAO                     NAO           NAO
# 9978                   NAO                     NAO           NAO
#
#      GELADEIRA_INCLUSO BANHEIRO_ADAPTADO         CLOSET COZINHA_AMERICANA  \
# 0                  NAO     NAO_INFORMADO  NAO_INFORMADO     NAO_INFORMADO
# 1                  NAO               NAO            NAO               NAO
# 2                  NAO               NAO            NAO               NAO
# 3                  NAO               NAO            NAO               NAO
# 4                  NAO               NAO            NAO               NAO
# ...                ...               ...            ...               ...
# 9974               NAO               NAO            NAO               NAO
# 9975               NAO               NAO            NAO               NAO
# 9976               NAO               SIM            NAO               NAO
# 9977               NAO     NAO_INFORMADO  NAO_INFORMADO     NAO_INFORMADO
# 9978               NAO               NAO            NAO               SIM
#
#      MESAS_E_CADEIRAS_DE_ESCRITORIO         JARDIM  \
# 0                     NAO_INFORMADO  NAO_INFORMADO
# 1                               NAO            NAO
# 2                               NAO            NAO
# 3                               SIM            NAO
# 4                               NAO            NAO
# ...                             ...            ...
# 9974                            NAO            NAO
# 9975                            NAO            NAO
# 9976                            NAO            SIM
# 9977                  NAO_INFORMADO  NAO_INFORMADO
# 9978                            NAO            NAO
#
#      QUARTOS_E_CORREDORES_COM_PORTAS_AMPLAS        QUINTAL  \
# 0                             NAO_INFORMADO  NAO_INFORMADO
# 1                                       NAO            SIM
# 2                                       NAO            NAO
# 3                                       NAO            NAO
# 4                                       NAO            NAO
# ...                                     ...            ...
# 9974                                    NAO            NAO
# 9975                                    NAO            NAO
# 9976                                    SIM            SIM
# 9977                          NAO_INFORMADO  NAO_INFORMADO
# 9978                                    NAO            NAO
#
#      SOMENTE_UMA_CASA_NO_TERRENO AREA_DE_SERVICO
# 0                  NAO_INFORMADO             SIM
# 1                            SIM             SIM
# 2                            NAO             SIM
# 3                            NAO             NAO
# 4                            NAO             SIM
# ...                          ...             ...
# 9974                         NAO             SIM
# 9975                         NAO             NAO
# 9976                         SIM             SIM
# 9977               NAO_INFORMADO   NAO_INFORMADO
# 9978                         NAO             SIM
#
# [9979 rows x 29 columns]

# %%
# Creating a unique dataset with relevant data
mask = [
    'id','bedrooms', 'city','bathrooms',
    'iptu','area','rentPrice',
    'type','iptuType','totalCost',
    'parkingSpaces','floor','suites',
    'street','neighborhood']
data_tmp = data_tmp.merge(data_raw[mask],how='left', right_on='id',left_on='id').drop(['type_x'],axis=1).rename(columns={'type_y':'type'})

# %% [markdown]
# ##### Creating dataset with properties of the São Paulo center

# %%
# Creating a list with neighborhoods of São Paulo center.
neighborhoods = [
    'Bela Vista','Bom Retiro','Cambuci','Consolação',
    'Sé','Higienópolis','Liberdade','Santa Cecília']

# %%
data_ = mount_filtered_dataframe(data_tmp, 'São Paulo', neighborhoods)

# %%
data_
# Out:
#             id        lat        lon BANHEIRA_DE_HIDROMASSAGEM  BOX  \
# 0    892790963 -23.555161 -46.641136                       NAO  SIM
# 1    893517945 -23.568121 -46.645794                       NAO  SIM
# 2    893262856 -23.563911 -46.643285                       NAO  SIM
# 3    893362687 -23.557757 -46.651662                       NAO  SIM
# 4    893550529 -23.556566 -46.654117                       NAO  SIM
# ..         ...        ...        ...                       ...  ...
# 815  893332194 -23.537155 -46.653981                       NAO  SIM
# 816  893650305 -23.536810 -46.655461                       SIM  SIM
# 817  893256178 -23.534069 -46.659916                       NAO  NAO
# 818  892843144 -23.533266 -46.658983                       NAO  SIM
# 819  892810116 -23.536785 -46.654997                       NAO  SIM
#
#            VARANDA PISCINA_PRIVATIVA ARMARIOS_EMBUTIDOS_NO_QUARTO  \
# 0    NAO_INFORMADO               NAO                          NAO
# 1              SIM               NAO                          SIM
# 2    NAO_INFORMADO               NAO                          SIM
# 3    NAO_INFORMADO               NAO                          SIM
# 4              NAO               NAO                          SIM
# ..             ...               ...                          ...
# 815  NAO_INFORMADO               NAO                          SIM
# 816            SIM               SIM                          SIM
# 817  NAO_INFORMADO               NAO                          NAO
# 818            NAO               NAO                          NAO
# 819  NAO_INFORMADO               NAO                          SIM
#
#     ARMARIOS_NOS_BANHEIROS ARMARIOS_NA_COZINHA AR_CONDICIONADO CHUVEIRO_A_GAS  \
# 0                      NAO                 SIM             NAO            SIM
# 1                      SIM                 SIM             SIM            SIM
# 2                      SIM                 SIM             NAO            SIM
# 3                      SIM                 SIM             NAO            NAO
# 4                      SIM                 SIM             NAO            NAO
# ..                     ...                 ...             ...            ...
# 815                    NAO                 NAO             NAO            NAO
# 816                    SIM                 SIM             NAO            SIM
# 817                    NAO                 NAO             NAO            NAO
# 818                    NAO                 SIM             NAO            NAO
# 819                    NAO                 SIM             NAO            NAO
#
#     QUARTO_DE_SERVICO BANHEIRO_DE_SERVICO VARANDA_GOURMET  \
# 0                 NAO                 NAO             NAO
# 1                 NAO                 NAO             NAO
# 2                 NAO                 NAO             NAO
# 3                 NAO                 NAO             NAO
# 4                 NAO                 NAO             NAO
# ..                ...                 ...             ...
# 815               NAO                 SIM             SIM
# 816               SIM                 SIM             SIM
# 817               NAO                 NAO             NAO
# 818               NAO                 NAO             NAO
# 819               NAO                 NAO             NAO
#
#     APARTAMENTO_COBERTURA QUARTO_EXTRA_REVERSIVEL FOGAO_INCLUSO  \
# 0                     NAO                     NAO           SIM
# 1                     NAO                     NAO           SIM
# 2                     NAO                     NAO           NAO
# 3                     NAO                     NAO           NAO
# 4                     NAO                     NAO           NAO
# ..                    ...                     ...           ...
# 815                   SIM                     NAO           NAO
# 816                   NAO                     SIM           NAO
# 817                   NAO                     NAO           NAO
# 818                   NAO                     NAO           NAO
# 819                   NAO                     NAO           SIM
#
#     GELADEIRA_INCLUSO BANHEIRO_ADAPTADO         CLOSET COZINHA_AMERICANA  \
# 0                 SIM     NAO_INFORMADO  NAO_INFORMADO     NAO_INFORMADO
# 1                 SIM               NAO            NAO               SIM
# 2                 NAO     NAO_INFORMADO  NAO_INFORMADO     NAO_INFORMADO
# 3                 NAO     NAO_INFORMADO  NAO_INFORMADO     NAO_INFORMADO
# 4                 NAO               NAO            NAO               NAO
# ..                ...               ...            ...               ...
# 815               NAO     NAO_INFORMADO  NAO_INFORMADO     NAO_INFORMADO
# 816               NAO               NAO            NAO               NAO
# 817               NAO     NAO_INFORMADO  NAO_INFORMADO     NAO_INFORMADO
# 818               NAO               NAO            NAO               SIM
# 819               SIM     NAO_INFORMADO  NAO_INFORMADO     NAO_INFORMADO
#
#     MESAS_E_CADEIRAS_DE_ESCRITORIO         JARDIM  \
# 0                    NAO_INFORMADO  NAO_INFORMADO
# 1                              NAO            NAO
# 2                    NAO_INFORMADO  NAO_INFORMADO
# 3                    NAO_INFORMADO  NAO_INFORMADO
# 4                              NAO            NAO
# ..                             ...            ...
# 815                  NAO_INFORMADO  NAO_INFORMADO
# 816                            NAO            NAO
# 817                  NAO_INFORMADO  NAO_INFORMADO
# 818                            NAO            NAO
# 819                  NAO_INFORMADO  NAO_INFORMADO
#
#     QUARTOS_E_CORREDORES_COM_PORTAS_AMPLAS        QUINTAL  \
# 0                            NAO_INFORMADO  NAO_INFORMADO
# 1                                      NAO            NAO
# 2                            NAO_INFORMADO  NAO_INFORMADO
# 3                            NAO_INFORMADO  NAO_INFORMADO
# 4                                      SIM            NAO
# ..                                     ...            ...
# 815                          NAO_INFORMADO  NAO_INFORMADO
# 816                                    NAO            NAO
# 817                          NAO_INFORMADO  NAO_INFORMADO
# 818                                    SIM            NAO
# 819                          NAO_INFORMADO  NAO_INFORMADO
#
#     SOMENTE_UMA_CASA_NO_TERRENO AREA_DE_SERVICO  bedrooms       city  \
# 0                 NAO_INFORMADO   NAO_INFORMADO       2.0  São Paulo
# 1                           NAO             SIM       1.0  São Paulo
# 2                 NAO_INFORMADO             SIM       3.0  São Paulo
# 3                 NAO_INFORMADO             SIM       3.0  São Paulo
# 4                           NAO             SIM       1.0  São Paulo
# ..                          ...             ...       ...        ...
# 815               NAO_INFORMADO   NAO_INFORMADO       1.0  São Paulo
# 816                         NAO             SIM       3.0  São Paulo
# 817               NAO_INFORMADO   NAO_INFORMADO       1.0  São Paulo
# 818                         NAO             SIM       1.0  São Paulo
# 819               NAO_INFORMADO   NAO_INFORMADO       1.0  São Paulo
#
#      bathrooms   iptu   area  rentPrice                 type   iptuType  \
# 0          1.0   81.0   70.0     2200.0          Apartamento     Normal
# 1          1.0  375.0   76.0     5090.0  StudioOuKitchenette     Normal
# 2          4.0  350.0  185.0     6750.0          Apartamento     Normal
# 3          2.0   85.0  110.0     3400.0          Apartamento     Normal
# 4          1.0    0.0   50.0     3750.0          Apartamento  NaoExiste
# ..         ...    ...    ...        ...                  ...        ...
# 815        1.0   47.0   43.0     1550.0          Apartamento     Normal
# 816        2.0  405.0  162.0     4000.0          Apartamento     Normal
# 817        1.0  125.0   30.0     2671.0          Apartamento     Normal
# 818        1.0    2.0   60.0     2200.0  StudioOuKitchenette     Normal
# 819        1.0    0.0   40.0     1700.0  StudioOuKitchenette  NaoExiste
#
#      totalCost  parkingSpaces  floor  suites                     street  \
# 0       3157.0            0.0   13.0     0.0               Rua Jaceguai
# 1       7641.0            1.0   14.0     1.0        Rua Cincinato Braga
# 2       9234.0            1.0    5.0     1.0            Rua Artur Prado
# 3       4711.0            1.0    7.0     1.0  Rua Doutor Plínio Barreto
# 4       4750.0            1.0    8.0     1.0         Rua Barata Ribeiro
# ..         ...            ...    ...     ...                        ...
# 815     2198.0            0.0    1.0     0.0             Alameda Barros
# 816     6174.0            1.0   13.0     1.0             Alameda Barros
# 817     3388.0            1.0   11.0     0.0    Rua Conselheiro Brotero
# 818     2715.0            0.0    7.0     0.0    Rua Conselheiro Brotero
# 819     2099.0            1.0   14.0     0.0             Alameda Barros
#
#       neighborhood
# 0       Bela Vista
# 1       Bela Vista
# 2       Bela Vista
# 3       Bela Vista
# 4       Bela Vista
# ..             ...
# 815  Santa Cecília
# 816  Santa Cecília
# 817  Santa Cecília
# 818  Santa Cecília
# 819  Santa Cecília
#
# [820 rows x 42 columns]
